# %%
# !git clone https://github.com/kuankuancjh2/SemanticTransformWrapper
# Out:
# Cloning into 'SemanticTransformWrapper'...
# remote: Enumerating objects: 103, done.
# remote: Counting objects: 100% (103/103), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 103 (delta 44), reused 83 (delta 29), pack-reused 0 (from 0)
# Receiving objects: 100% (103/103), 82.52 KiB | 13.75 MiB/s, done.
# Resolving deltas: 100% (44/44), done.

# %%
# !git pull https://github.com/kuankuancjh2/SemanticTransformWrapper
# Out:
# /bin/bash: line 1: cd..: command not found
# remote: Enumerating objects: 12, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6 (delta 4), reused 6 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (6/6), 754 bytes | 377.00 KiB/s, done.
# From https://github.com/kuankuancjh2/SemanticTransformWrapper
#  * branch            HEAD       -> FETCH_HEAD
# Updating 1fbbb4c..30efc6c
# error: Your local changes to the following files would be overwritten by merge:
# 	configs/config.yaml
# Please commit your changes or stash them before you merge.
# Aborting
# /bin/bash: line 1: cd: SemanticTransformWrapper: No such file or directory

# %%
# !git merge
# Out:
# Already up to date.

# %%
cd SemanticTransformWrapper
# Out:
# /kaggle/working/SemanticTransformWrapper

# %%
# !python prepare_data.py
# Out:
# 2026-09-25 03:19:48,638 | INFO    | numexpr.utils | NumExpr defaulting to 4 threads.
# 2026-09-25 03:19:49,686 | INFO    | datasets | TensorFlow version 2.20.0 available.
# 2026-09-25 03:19:49,688 | INFO    | datasets | JAX version 0.7.2 available.
# 2026-09-25 03:19:51,191 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/refs%2Fconvert%2Fparquet/README.md "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-25 03:19:51,192 | WARNING | huggingface_hub.utils._http | Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-25 03:19:51,224 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/revision/refs%2Fconvert%2Fparquet "HTTP/1.1 200 OK"
# 2026-09-25 03:19:51,240 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/dailydialog.py "HTTP/1.1 404 Not Found"
# 2026-09-25 03:19:51,276 | INFO    | httpx | HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/roskoN/dailydialog/roskoN/dailydialog.py "HTTP/1.1 404 Not Found"
# 2026-09-25 03:19:51,294 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/README.md "HTTP/1.1 404 Not Found"
# 2026-09-25 03:19:51,319 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/revision/f9b0ba89e62d91641632652722b479b5c65ae4b6 "HTTP/1.1 200 OK"
# 2026-09-25 03:19:51,334 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-09-25 03:19:51,376 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6/data?recursive=true&expand=false "HTTP/1.1 404 Not Found"
# 2026-09-25 03:19:51,441 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6?recursive=false&expand=false "HTTP/1.1 200 OK"
# 2026-09-25 03:19:51,507 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6/full?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-09-25 03:19:51,542 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-09-25 03:19:51,690 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/train/0000.parquet "HTTP/1.1 302 Found"
# 2026-09-25 03:19:51,745 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/xet-read-token/f9b0ba89e62d91641632652722b479b5c65ae4b6 "HTTP/1.1 200 OK"
# full/train/0000.parquet: 100%|█████████████| 3.67M/3.67M [00:00<00:00, 8.25MB/s]
# 2026-09-25 03:19:52,209 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/validation/0000.parquet "HTTP/1.1 307 Temporary Redirect"
# 2026-09-25 03:19:52,216 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Fvalidation%2F0000.parquet "HTTP/1.1 200 OK"
# 2026-09-25 03:19:52,224 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Fvalidation%2F0000.parquet "HTTP/1.1 200 OK"
# 0000.parquet: 100%|██████████████████████████| 340k/340k [00:00<00:00, 35.5MB/s]
# 2026-09-25 03:19:52,252 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/test/0000.parquet "HTTP/1.1 307 Temporary Redirect"
# 2026-09-25 03:19:52,259 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Ftest%2F0000.parquet "HTTP/1.1 200 OK"
# 2026-09-25 03:19:52,271 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Ftest%2F0000.parquet "HTTP/1.1 200 OK"
# 0000.parquet: 100%|███████████████████████████| 337k/337k [00:00<00:00, 137MB/s]
# Generating train split: 11118 examples [00:00, 172410.72 examples/s]
# Generating validation split: 1000 examples [00:00, 194216.71 examples/s]
# Generating test split: 1000 examples [00:00, 197128.54 examples/s]
# 2026-09-25 03:19:53,141 | INFO    | prepare_data | Loaded 89861 dialogue pairs from HF dataset roskoN/dailydialog
# [00:00:00] Tokenize words                 ██████████████████ 23200    /    23200[00:00:00] Tokenize words                 ██████████████████ 0        /        0
# [00:00:00] Count pairs                    ██████████████████ 23200    /    23200
# [00:00:00] Compute merges                 ██████████████████ 15740    /    15740
# 2026-09-25 03:19:56,436 | INFO    | prepare_data | Data ready: {"source": "hf:roskoN/dailydialog", "offline_used": false, "train_size": 82673, "val_size": 3594, "test_size": 3594, "stage1_train_size": 82673, "vocab_size": 16000, "tokenizer": "data/cache/tokenizer_bpe.json", "mean_len_tokens": 15.337, "max_len_tokens": 103, "p99_len_tokens": 57}

# %%
# !python train_stage1.py --resume checkpoints/stage1/best.pt
# Out:
# 2026-09-25 13:41:38,713 | INFO    | stage1 | Resumed stage1 from checkpoints/stage1/best.pt (epoch 0, step 2000)
# stage1 epoch0:   2%|█                                                       | 49/2583 [00:19<13:21,  3.16it/s]/kaggle/working/SemanticTransformWrapper/src/training/stage1.py:196: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   writer.add_scalar("loss/variance", float(l_var), gstep)
# stage1 epoch0:  39%|███████▋            | 999/2583 [06:57<11:11,  2.36it/s, kl=22.76, loss=4.215, recon=3.538]2026-09-25 13:48:49,891 | INFO    | stage1 | val @3000: loss=4.647 ppl=36.29 acc=0.395 latent_std=0.163 cos=0.154 eff_rank=14.0 kl=24.262 au=512
# 2026-09-25 13:48:51,354 | INFO    | train | Preview saved: samples/step_003000.txt
# stage1 epoch0:  77%|██████████████▋    | 1999/2583 [14:17<04:05,  2.37it/s, kl=24.60, loss=3.893, recon=3.213]2026-09-25 13:56:09,245 | INFO    | stage1 | val @4000: loss=4.302 ppl=25.79 acc=0.442 latent_std=0.172 cos=0.163 eff_rank=11.5 kl=23.429 au=512
# 2026-09-25 13:56:11,441 | INFO    | train | Preview saved: samples/step_004000.txt
# stage1 epoch0: 100%|███████████████████| 2583/2583 [18:44<00:00,  2.30it/s, kl=23.95, loss=3.539, recon=2.851]
# stage1 epoch1:  16%|███▏                | 416/2583 [02:52<12:22,  2.92it/s, kl=23.26, loss=3.547, recon=2.860]2026-09-25 14:03:28,423 | INFO    | stage1 | val @5000: loss=4.077 ppl=20.74 acc=0.470 latent_std=0.178 cos=0.145 eff_rank=11.9 kl=23.968 au=512
# 2026-09-25 14:03:29,663 | INFO    | train | Preview saved: samples/step_005000.txt
# stage1 epoch1:  55%|██████████▍        | 1416/2583 [10:10<07:47,  2.50it/s, kl=25.20, loss=3.375, recon=2.678]2026-09-25 14:10:46,299 | INFO    | stage1 | val @6000: loss=3.870 ppl=16.90 acc=0.499 latent_std=0.185 cos=0.136 eff_rank=12.0 kl=24.553 au=512
# 2026-09-25 14:10:47,882 | INFO    | train | Preview saved: samples/step_006000.txt
# stage1 epoch1:  94%|█████████████████▊ | 2416/2583 [17:32<01:10,  2.36it/s, kl=23.63, loss=3.407, recon=2.713]2026-09-25 14:18:08,384 | INFO    | stage1 | val @7000: loss=3.722 ppl=14.65 acc=0.519 latent_std=0.190 cos=0.111 eff_rank=11.9 kl=23.939 au=512
# 2026-09-25 14:18:10,404 | INFO    | train | Preview saved: samples/step_007000.txt
# stage1 epoch1: 100%|███████████████████| 2583/2583 [19:01<00:00,  2.26it/s, kl=23.45, loss=3.106, recon=2.411]
# stage1 epoch2:  32%|██████▍             | 833/2583 [05:48<10:23,  2.81it/s, kl=25.00, loss=2.698, recon=1.996]2026-09-25 14:25:25,294 | INFO    | stage1 | val @8000: loss=3.635 ppl=13.40 acc=0.532 latent_std=0.198 cos=0.122 eff_rank=11.7 kl=25.476 au=512
# 2026-09-25 14:25:26,813 | INFO    | train | Preview saved: samples/step_008000.txt
# stage1 epoch2:  71%|█████████████▍     | 1833/2583 [13:08<04:26,  2.82it/s, kl=24.14, loss=2.692, recon=1.992]2026-09-25 14:32:46,112 | INFO    | stage1 | val @9000: loss=3.529 ppl=12.22 acc=0.547 latent_std=0.195 cos=0.112 eff_rank=11.5 kl=24.600 au=512
# 2026-09-25 14:32:47,509 | INFO    | train | Preview saved: samples/step_009000.txt
# stage1 epoch2: 100%|███████████████████| 2583/2583 [18:43<00:00,  2.30it/s, kl=24.43, loss=2.733, recon=2.033]
# stage1 epoch3:  10%|█▉                  | 250/2583 [01:45<14:44,  2.64it/s, kl=26.26, loss=2.269, recon=1.558]2026-09-25 14:40:05,879 | INFO    | stage1 | val @10000: loss=3.479 ppl=11.67 acc=0.555 latent_std=0.198 cos=0.122 eff_rank=11.5 kl=25.039 au=512
# 2026-09-25 14:40:07,606 | INFO    | train | Preview saved: samples/step_010000.txt
# stage1 epoch3:  48%|█████████▏         | 1250/2583 [09:02<08:38,  2.57it/s, kl=24.02, loss=2.259, recon=1.554]2026-09-25 14:47:23,623 | INFO    | stage1 | val @11000: loss=3.416 ppl=11.08 acc=0.569 latent_std=0.200 cos=0.121 eff_rank=11.6 kl=24.992 au=512
# 2026-09-25 14:47:25,026 | INFO    | train | Preview saved: samples/step_011000.txt
# stage1 epoch3:  87%|████████████████▌  | 2250/2583 [16:22<02:20,  2.36it/s, kl=24.05, loss=2.346, recon=1.644]2026-09-25 14:54:42,822 | INFO    | stage1 | val @12000: loss=3.367 ppl=10.64 acc=0.577 latent_std=0.198 cos=0.112 eff_rank=11.3 kl=24.296 au=512
# 2026-09-25 14:54:44,055 | INFO    | train | Preview saved: samples/step_012000.txt
# stage1 epoch3: 100%|███████████████████| 2583/2583 [19:04<00:00,  2.26it/s, kl=23.76, loss=2.340, recon=1.634]
# stage1 epoch4:  26%|█████▏              | 667/2583 [04:39<11:46,  2.71it/s, kl=23.47, loss=1.999, recon=1.289]2026-09-25 15:02:04,128 | INFO    | stage1 | val @13000: loss=3.342 ppl=10.49 acc=0.585 latent_std=0.198 cos=0.109 eff_rank=11.5 kl=24.225 au=512
# 2026-09-25 15:02:05,662 | INFO    | train | Preview saved: samples/step_013000.txt
# stage1 epoch4:  65%|████████████▎      | 1667/2583 [11:56<06:27,  2.36it/s, kl=25.62, loss=1.997, recon=1.284]2026-09-25 15:09:20,992 | INFO    | stage1 | val @14000: loss=3.308 ppl=10.19 acc=0.594 latent_std=0.200 cos=0.118 eff_rank=11.5 kl=25.434 au=512
# 2026-09-25 15:09:22,272 | INFO    | train | Preview saved: samples/step_014000.txt
# stage1 epoch4: 100%|███████████████████| 2583/2583 [18:42<00:00,  2.30it/s, kl=25.10, loss=1.977, recon=1.267]
# stage1 epoch5:   3%|▋                    | 84/2583 [00:35<17:45,  2.35it/s, kl=25.44, loss=2.003, recon=1.295]2026-09-25 15:16:43,538 | INFO    | stage1 | val @15000: loss=3.287 ppl=10.09 acc=0.601 latent_std=0.203 cos=0.130 eff_rank=11.4 kl=24.894 au=512
# 2026-09-25 15:16:45,012 | INFO    | train | Preview saved: samples/step_015000.txt
# stage1 epoch5:  42%|███████▉           | 1084/2583 [07:54<10:45,  2.32it/s, kl=25.20, loss=2.029, recon=1.316]2026-09-25 15:24:02,596 | INFO    | stage1 | val @16000: loss=3.304 ppl=10.43 acc=0.603 latent_std=0.199 cos=0.105 eff_rank=11.3 kl=25.259 au=512
# 2026-09-25 15:24:04,023 | INFO    | train | Preview saved: samples/step_016000.txt
# stage1 epoch5:  81%|███████████████▎   | 2084/2583 [15:15<03:35,  2.32it/s, kl=23.01, loss=1.813, recon=1.106]2026-09-25 15:31:23,354 | INFO    | stage1 | val @17000: loss=3.280 ppl=10.25 acc=0.608 latent_std=0.199 cos=0.122 eff_rank=11.2 kl=24.200 au=512
# 2026-09-25 15:31:24,541 | INFO    | train | Preview saved: samples/step_017000.txt
# stage1 epoch5: 100%|███████████████████| 2583/2583 [19:03<00:00,  2.26it/s, kl=24.86, loss=1.865, recon=1.153]
# stage1 epoch6:  19%|███▉                | 501/2583 [03:27<13:52,  2.50it/s, kl=25.63, loss=1.833, recon=1.123]2026-09-25 15:38:39,342 | INFO    | stage1 | val @18000: loss=3.293 ppl=10.52 acc=0.615 latent_std=0.197 cos=0.113 eff_rank=11.6 kl=25.966 au=512
# 2026-09-25 15:38:40,935 | INFO    | train | Preview saved: samples/step_018000.txt
# stage1 epoch6:  33%|██████▋             | 865/2583 [06:17<11:07,  2.57it/s, kl=24.04, loss=1.761, recon=1.061]^C
# stage1 epoch6:  33%|██████▋             | 865/2583 [06:17<12:29,  2.29it/s, kl=24.04, loss=1.761, recon=1.061]
# Traceback (most recent call last):
#   File "/kaggle/working/SemanticTransformWrapper/train_stage1.py", line 67, in <module>
#     main()
#   File "/kaggle/working/SemanticTransformWrapper/train_stage1.py", line 63, in main
#     train_stage1(cfg, resume=args.resume)
#   File "/kaggle/working/SemanticTransformWrapper/src/training/stage1.py", line 139, in train_stage1
#     prompt = batch["prompt"].to(device)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python train_stage2.py --stage1-checkpoint checkpoints/stage1/best.pt
# Out:
# stage2[bihopfield] epoch0:   2%|▊                                           | 49/2583 [00:10<08:08,  5.19it/s]/kaggle/working/SemanticTransformWrapper/src/training/stage2.py:167: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   writer.add_scalar("loss/latent", float(lset["latent"]), gstep)
# stage2[bihopfield] epoch0:  39%|███▍     | 999/2583 [03:32<05:19,  4.96it/s, dec=3.199, lat=0.186, loss=3.385]2026-09-24 04:20:20,270 | INFO    | stage2 | val @1000: loss=4.051 decode=3.875 latent=0.177 ppl=54.57 dep=1.520
# 2026-09-24 04:20:21,751 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_001000.txt
# stage2[bihopfield] epoch0:  77%|██████▏ | 1999/2583 [07:26<02:40,  3.64it/s, dec=2.934, lat=0.125, loss=3.060]2026-09-24 04:24:14,880 | INFO    | stage2 | val @2000: loss=3.919 decode=3.789 latent=0.130 ppl=50.06 dep=1.606
# 2026-09-24 04:24:16,956 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_002000.txt
# stage2[bihopfield] epoch0: 100%|████████| 2583/2583 [09:56<00:00,  4.33it/s, dec=2.826, lat=0.104, loss=2.929]
# stage2[bihopfield] epoch1:  16%|█▍       | 416/2583 [01:27<06:48,  5.30it/s, dec=2.501, lat=0.117, loss=2.617]2026-09-24 04:28:11,464 | INFO    | stage2 | val @3000: loss=3.867 decode=3.753 latent=0.114 ppl=48.56 dep=1.642
# 2026-09-24 04:28:12,990 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_003000.txt
# stage2[bihopfield] epoch1:  55%|████▍   | 1416/2583 [05:22<04:13,  4.61it/s, dec=3.248, lat=0.114, loss=3.362]2026-09-24 04:32:07,008 | INFO    | stage2 | val @4000: loss=3.838 decode=3.730 latent=0.109 ppl=47.39 dep=1.665
# 2026-09-24 04:32:08,343 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_004000.txt
# stage2[bihopfield] epoch1:  94%|███████▍| 2416/2583 [09:20<00:35,  4.68it/s, dec=2.820, lat=0.097, loss=2.917]2026-09-24 04:36:04,287 | INFO    | stage2 | val @5000: loss=3.815 decode=3.713 latent=0.102 ppl=46.58 dep=1.682
# 2026-09-24 04:36:05,524 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_005000.txt
# stage2[bihopfield] epoch1: 100%|████████| 2583/2583 [10:17<00:00,  4.18it/s, dec=2.598, lat=0.100, loss=2.698]
# stage2[bihopfield] epoch2:  32%|██▉      | 833/2583 [02:55<06:07,  4.76it/s, dec=2.676, lat=0.101, loss=2.778]2026-09-24 04:39:57,486 | INFO    | stage2 | val @6000: loss=3.813 decode=3.714 latent=0.099 ppl=46.70 dep=1.681
# 2026-09-24 04:39:58,848 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_006000.txt
# stage2[bihopfield] epoch2:  71%|█████▋  | 1833/2583 [06:49<02:30,  4.98it/s, dec=2.759, lat=0.084, loss=2.843]2026-09-24 04:43:51,862 | INFO    | stage2 | val @7000: loss=3.793 decode=3.697 latent=0.096 ppl=45.87 dep=1.698
# 2026-09-24 04:43:53,027 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_007000.txt
# stage2[bihopfield] epoch2: 100%|████████| 2583/2583 [09:52<00:00,  4.36it/s, dec=2.986, lat=0.091, loss=3.078]
# stage2[bihopfield] epoch3:  10%|▊        | 250/2583 [00:53<07:20,  5.30it/s, dec=3.015, lat=0.101, loss=3.116]2026-09-24 04:47:48,484 | INFO    | stage2 | val @8000: loss=3.787 decode=3.692 latent=0.095 ppl=45.70 dep=1.703
# 2026-09-24 04:47:49,837 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_008000.txt
# stage2[bihopfield] epoch3:  48%|███▊    | 1250/2583 [04:49<04:42,  4.72it/s, dec=2.710, lat=0.103, loss=2.812]2026-09-24 04:51:43,950 | INFO    | stage2 | val @9000: loss=3.781 decode=3.685 latent=0.096 ppl=45.25 dep=1.710
# 2026-09-24 04:51:45,475 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_009000.txt
# stage2[bihopfield] epoch3:  87%|██████▉ | 2250/2583 [08:42<01:17,  4.28it/s, dec=2.441, lat=0.092, loss=2.533]2026-09-24 04:55:37,052 | INFO    | stage2 | val @10000: loss=3.781 decode=3.689 latent=0.092 ppl=45.50 dep=1.706
# 2026-09-24 04:55:38,595 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_010000.txt
# stage2[bihopfield] epoch3: 100%|████████| 2583/2583 [10:15<00:00,  4.20it/s, dec=2.534, lat=0.096, loss=2.630]
# stage2[bihopfield] epoch4:  26%|██▎      | 667/2583 [02:22<06:28,  4.94it/s, dec=2.728, lat=0.092, loss=2.820]2026-09-24 04:59:32,143 | INFO    | stage2 | val @11000: loss=3.768 decode=3.675 latent=0.092 ppl=44.80 dep=1.720
# 2026-09-24 04:59:33,648 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_011000.txt
# stage2[bihopfield] epoch4:  65%|█████▏  | 1667/2583 [06:14<02:54,  5.24it/s, dec=2.914, lat=0.096, loss=3.010]2026-09-24 05:03:24,901 | INFO    | stage2 | val @12000: loss=3.754 decode=3.664 latent=0.091 ppl=44.50 dep=1.731
# 2026-09-24 05:03:26,819 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_012000.txt
# stage2[bihopfield] epoch4: 100%|████████| 2583/2583 [09:52<00:00,  4.36it/s, dec=3.018, lat=0.094, loss=3.112]
# stage2[bihopfield] epoch5:   3%|▎         | 84/2583 [00:17<09:52,  4.22it/s, dec=2.661, lat=0.088, loss=2.749]^C
# stage2[bihopfield] epoch5:   3%|▎         | 84/2583 [00:23<11:30,  3.62it/s, dec=2.661, lat=0.088, loss=2.749]
# Traceback (most recent call last):
#   File "/kaggle/working/SemanticTransformWrapper/train_stage2.py", line 61, in <module>
#     main()
#   File "/kaggle/working/SemanticTransformWrapper/train_stage2.py", line 56, in main
#     train_stage2(cfg, args.stage1_checkpoint, resume=args.resume,
#   File "/kaggle/working/SemanticTransformWrapper/src/training/stage2.py", line 175, in train_stage2
#     vs = validate_stage2(model, val_loader, cfg, device, tok.pad_id)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/training/stage2.py", line 45, in validate_stage2
#     out = model(prompt, pmask, target, tmask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/model/model.py", line 120, in forward
#     z_pred = self.transform(z_p)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/model/model.py", line 107, in transform
#     return self.core(z_prompt)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/model/cores.py", line 131, in forward
#     attn = torch.softmax(self.beta * state @ state.transpose(-1, -2), dim=-1)
#                                              ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "Do you like watch "
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.2888
# generated    : Do you like watch ivory ?

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "The weather today is clear, so "
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.2023
# generated    : The weather today is clear, so ivating in summer .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "Birds have "
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.1562
# generated    : Birds have ivated .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "The sun today is"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.2608
# generated    : The sun today is a big mistake .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "Something goes wrong with"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.3083
# generated    : Something goes wrong with my friends .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "The mooncakes are"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.3819
# generated    : The mooncakes are not usually available .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "My mother"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.0286
# generated    : My mother-in-law is driving me up .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "So what do you think of"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.3241
# generated    : So what do you think of the job ?

# %%
# !python evaluate.py --checkpoint checkpoints/stage2/best.pt
# Out:
# {
#   "checkpoint": "checkpoints/stage2/best.pt",
#   "semantic_tests": {
#     "paraphrase_same_meaning": 0.9985436201095581,
#     "different_meaning": 0.9871141910552979,
#     "subject_swap": 0.9869921207427979,
#     "object_swap": 0.9884764552116394,
#     "surface_variation": 0.994475781917572,
#     "surface_variation2": 0.9986733794212341,
#     "contrast_margin": 0.011429429054260254
#   },
#   "latent_stats": {
#     "std": 1.2915661334991455,
#     "norm": 28.64149284362793,
#     "cos_sim": 0.023111237213015556,
#     "cov_off": 63.90997314453125,
#     "eff_rank": 19.97808837890625
#   },
#   "interventions": {
#     "interpolation": {
#       "alpha=0.0": "小明吃苹果 .",
#       "alpha=0.25": "小明吃苹果 .",
#       "alpha=0.5": "小明吃苹果 .",
#       "alpha=0.75": "小明吃苹果 .",
#       "alpha=1.0": "小明吃苹果 ."
#     },
#     "latent_noise": {
#       "std=0.1": "小明吃苹果 .",
#       "std=0.5": "小明吃苹果 .",
#       "std=1.0": "小明吃苹果 a very easily . I have this morning feeling near my work . I was wondering about it that we can take public transportation system to get a home with a home-cons .\nI agree . It's a very convenient way for you can get a very easily ."
#     },
#     "token_masking_half": "小明吃苹果 you have a chance to readership numbers . I think I should try my best .\nWhat's the problem ?",
#     "token_swapping": "小明吃苹果 .",
#     "dim_masking_half": "小明吃苹果 .\nI see . I am a student here in the States , and it's not as practical .",
#     "generate_real_latent": "小明吃苹果 .",
#     "generate_zero_latent": "小明吃苹果 you have a lot of experience .\nI'm so sorry , I didn't know that . But the first thing is to be in your mind .\nWhat are they doing ?",
#     "latent_dependency_note": "if real == zero, the decoder is ignoring the semantic representation"
#   },
#   "probes": {
#     "semantic_subject_acc": 0.0,
#     "semantic_object_acc": 0.0,
#     "surface_last_char_acc": 0.1875,
#     "surface_length_bucket_acc": 0.3125
#   }
# }
#
# [saved] eval_report.json

# %%
# !python inspect_latent.py --checkpoint checkpoints/stage1/best.pt
# Out:
# 2026-09-24 05:19:00,346 | INFO    | numexpr.utils | NumExpr defaulting to 4 threads.
# saved: ['latent_covariance.png', 'latent_norm.png', 'latent_pca.png', 'latent_similarity.png', 'latent_tsne.png']

# %%
# !cp -rf checkpoints/stage1/best.zip /kaggle/output

# %%
# !cp -rf checkpoints/stage2/best.zip /kaggle/output

# %%
cd SemanticTransformWrapper
# Out:
# [Errno 2] No such file or directory: 'SemanticTransformWrapper'
# /kaggle/working/SemanticTransformWrapper

# %%
from IPython.display import FileLink
FileLink("../output/best.zip")
# Out:
# /kaggle/working/output/best.zip

# %%
ls src/evaluation
# Out:
# __init__.py  __pycache__/  semantic_eval.py

# %%
# !rm src/evaluation/semantic_eval.py

# %%
# !python evaluate.py --checkpoint checkpoints/stage2/best.pt
# Out:
# {
#   "checkpoint": "checkpoints/stage2/best.pt",
#   "semantic_tests": {
#     "paraphrase_same_meaning": 0.9642701148986816,
#     "different_meaning": 0.958402693271637,
#     "subject_swap": 0.982008695602417,
#     "object_swap": 0.9762095212936401,
#     "surface_variation": 0.9833912253379822,
#     "surface_variation2": 0.9642701148986816,
#     "contrast_margin": 0.005867421627044678
#   },
#   "latent_stats": {
#     "std": 1.2915661334991455,
#     "norm": 28.64149284362793,
#     "cos_sim": 0.023111237213015556,
#     "cov_off": 63.90997314453125,
#     "eff_rank": 19.97808837890625
#   },
#   "interventions": {
#     "interpolation": {
#       "alpha=0.0": "Alice eats an apple.And then you'll have to pay for it .",
#       "alpha=0.25": "Alice eats an apple.And then you'll have to pay for it .",
#       "alpha=0.5": "Alice eats an apple.And then you'll have to pay for it .",
#       "alpha=0.75": "Alice eats an apple.And then you'll have to pay a minimum balance of $ 200 in advance .",
#       "alpha=1.0": "Alice eats an apple.And then you'll have to pay a minimum balance of $ 200 ."
#     },
#     "latent_noise": {
#       "std=0.1": "Alice eats an apple.And then you'll have to pay for it .",
#       "std=0.5": "Alice eats an apple.And then you'll have to pay for the whole five percent discount of them .",
#       "std=1.0": "Alice eats an apple.com is so excellent ."
#     },
#     "token_masking_half": "Alice eats an apple.And then you could use the telex machine here .",
#     "token_swapping": "Alice eats an apple.And then you'll have to pay a minimum balance of $ 200 in advance .",
#     "dim_masking_half": "Alice eats an apple.com is a big mistake , you should have it .\nI'm sorry . I didn't know that . But now you're going to take care of all the junk food into two weeks .",
#     "generate_real_latent": "Alice eats an apple.And then you'll have to pay for it .",
#     "generate_zero_latent": "Alice eats an apple.com is a big fan of things to do .\nI'm sorry , but I didn't know that .\nLet me examine you . Ernie , and your company has been very good at the end of this year . How about you ?",
#     "latent_dependency_note": "if real == zero, the decoder is ignoring the semantic representation"
#   },
#   "probes": {
#     "semantic_subject_acc": 0.0,
#     "semantic_object_acc": 0.1764705926179886,
#     "surface_last_char_acc": 0.1875,
#     "surface_length_bucket_acc": 0.3125
#   }
# }
#
# [saved] eval_report.json

# %%
# !python inspect_latent.py --checkpoint checkpoints/stage1/best.pt
# Out:
# 2026-09-24 16:45:46,041 | INFO    | numexpr.utils | NumExpr defaulting to 4 threads.
# saved: ['latent_covariance.png', 'latent_norm.png', 'latent_pca.png', 'latent_similarity.png', 'latent_tsne.png']
