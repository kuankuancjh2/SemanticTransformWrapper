# %%
# !git clone https://github.com/kuankuancjh2/SemanticTransformWrapper
# Out:
# Cloning into 'SemanticTransformWrapper'...
# remote: Enumerating objects: 70, done.
# remote: Counting objects: 100% (70/70), done.
# remote: Compressing objects: 100% (49/49), done.
# remote: Total 70 (delta 21), reused 64 (delta 17), pack-reused 0 (from 0)
# Receiving objects: 100% (70/70), 54.61 KiB | 1.16 MiB/s, done.
# Resolving deltas: 100% (21/21), done.

# %%
cd SemanticTransformWrapper
# Out:
# /kaggle/working/SemanticTransformWrapper

# %%
# !python prepare_data.py
# Out:
# 2026-09-24 01:48:03,266 | INFO    | numexpr.utils | NumExpr defaulting to 4 threads.
# 2026-09-24 01:48:04,398 | INFO    | datasets | TensorFlow version 2.20.0 available.
# 2026-09-24 01:48:04,402 | INFO    | datasets | JAX version 0.7.2 available.
# 2026-09-24 01:48:06,101 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/refs%2Fconvert%2Fparquet/README.md "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-24 01:48:06,102 | WARNING | huggingface_hub.utils._http | Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-24 01:48:06,285 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/revision/refs%2Fconvert%2Fparquet "HTTP/1.1 200 OK"
# 2026-09-24 01:48:06,344 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/dailydialog.py "HTTP/1.1 404 Not Found"
# 2026-09-24 01:48:06,435 | INFO    | httpx | HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/roskoN/dailydialog/roskoN/dailydialog.py "HTTP/1.1 404 Not Found"
# 2026-09-24 01:48:06,495 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/README.md "HTTP/1.1 404 Not Found"
# 2026-09-24 01:48:06,566 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/revision/f9b0ba89e62d91641632652722b479b5c65ae4b6 "HTTP/1.1 200 OK"
# 2026-09-24 01:48:06,624 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-09-24 01:48:06,713 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6/data?recursive=true&expand=false "HTTP/1.1 404 Not Found"
# 2026-09-24 01:48:06,791 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6?recursive=false&expand=false "HTTP/1.1 200 OK"
# 2026-09-24 01:48:06,866 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6/full?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-09-24 01:48:06,949 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-09-24 01:48:07,130 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/train/0000.parquet "HTTP/1.1 302 Found"
# 2026-09-24 01:48:07,235 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/xet-read-token/f9b0ba89e62d91641632652722b479b5c65ae4b6 "HTTP/1.1 200 OK"
# full/train/0000.parquet: 100%|█████████████| 3.67M/3.67M [00:00<00:00, 5.75MB/s]
# 2026-09-24 01:48:07,937 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/validation/0000.parquet "HTTP/1.1 307 Temporary Redirect"
# 2026-09-24 01:48:07,953 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Fvalidation%2F0000.parquet "HTTP/1.1 200 OK"
# 2026-09-24 01:48:07,972 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Fvalidation%2F0000.parquet "HTTP/1.1 200 OK"
# 0000.parquet: 100%|██████████████████████████| 340k/340k [00:00<00:00, 10.5MB/s]
# 2026-09-24 01:48:08,068 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/test/0000.parquet "HTTP/1.1 307 Temporary Redirect"
# 2026-09-24 01:48:08,085 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Ftest%2F0000.parquet "HTTP/1.1 200 OK"
# 2026-09-24 01:48:08,101 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Ftest%2F0000.parquet "HTTP/1.1 200 OK"
# 0000.parquet: 100%|██████████████████████████| 337k/337k [00:00<00:00, 54.4MB/s]
# Generating train split: 11118 examples [00:00, 179689.39 examples/s]
# Generating validation split: 1000 examples [00:00, 161338.00 examples/s]
# Generating test split: 1000 examples [00:00, 202125.39 examples/s]
# 2026-09-24 01:48:09,011 | INFO    | prepare_data | Loaded 89861 dialogue pairs from HF dataset roskoN/dailydialog
# [00:00:00] Tokenize words                 ██████████████████ 23200    /    23200[00:00:00] Tokenize words                 ██████████████████ 0        /        0
# [00:00:00] Count pairs                    ██████████████████ 23200    /    23200
# [00:00:00] Compute merges                 ██████████████████ 15740    /    15740
# 2026-09-24 01:48:12,409 | INFO    | prepare_data | Data ready: {"source": "hf:roskoN/dailydialog", "offline_used": false, "train_size": 82673, "val_size": 3594, "test_size": 3594, "stage1_train_size": 82673, "vocab_size": 16000, "tokenizer": "data/cache/tokenizer_bpe.json", "mean_len_tokens": 15.337, "max_len_tokens": 103, "p99_len_tokens": 57}

# %%
# !python train_stage1.py
# Out:
# stage1 epoch0:   2%|█                                                       | 49/2583 [00:19<13:16,  3.18it/s]/kaggle/working/SemanticTransformWrapper/src/training/stage1.py:158: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   writer.add_scalar("loss/variance", float(l_var), gstep)
# stage1 epoch0:  39%|███████████▌                  | 999/2583 [07:36<12:26,  2.12it/s, loss=5.461, recon=4.857]2026-09-24 01:56:34,004 | INFO    | stage1 | val @1000: loss=5.468 ppl=108.32 acc=0.259 latent_std=0.283 cos=0.608 eff_rank=30.9
# 2026-09-24 01:56:37,765 | INFO    | train | Preview saved: samples/step_001000.txt
# stage1 epoch0:  77%|██████████████████████▍      | 1999/2583 [15:48<04:28,  2.17it/s, loss=4.714, recon=4.160]2026-09-24 02:04:45,132 | INFO    | stage1 | val @2000: loss=5.020 ppl=70.95 acc=0.297 latent_std=0.307 cos=0.557 eff_rank=31.7
# 2026-09-24 02:04:50,083 | INFO    | train | Preview saved: samples/step_002000.txt
# stage1 epoch0: 100%|█████████████████████████████| 2583/2583 [20:45<00:00,  2.07it/s, loss=4.331, recon=3.789]
# stage1 epoch1:  16%|████▊                         | 416/2583 [03:16<16:26,  2.20it/s, loss=4.228, recon=3.696]2026-09-24 02:12:59,304 | INFO    | stage1 | val @3000: loss=4.690 ppl=51.49 acc=0.340 latent_std=0.290 cos=0.396 eff_rank=35.2
# 2026-09-24 02:13:08,161 | INFO    | train | Preview saved: samples/step_003000.txt
# stage1 epoch1:  55%|███████████████▉             | 1416/2583 [11:32<12:13,  1.59it/s, loss=4.062, recon=3.537]2026-09-24 02:21:15,502 | INFO    | stage1 | val @4000: loss=4.510 ppl=43.32 acc=0.358 latent_std=0.296 cos=0.327 eff_rank=34.0
# 2026-09-24 02:21:19,693 | INFO    | train | Preview saved: samples/step_004000.txt
# stage1 epoch1:  94%|███████████████████████████▏ | 2416/2583 [19:43<01:02,  2.66it/s, loss=4.109, recon=3.587]2026-09-24 02:29:26,054 | INFO    | stage1 | val @5000: loss=4.302 ppl=35.26 acc=0.392 latent_std=0.312 cos=0.309 eff_rank=34.2
# 2026-09-24 02:29:28,758 | INFO    | train | Preview saved: samples/step_005000.txt
# stage1 epoch1: 100%|█████████████████████████████| 2583/2583 [21:21<00:00,  2.01it/s, loss=4.043, recon=3.525]
# stage1 epoch2:  32%|█████████▋                    | 833/2583 [06:29<12:38,  2.31it/s, loss=4.090, recon=3.576]2026-09-24 02:37:34,291 | INFO    | stage1 | val @6000: loss=4.125 ppl=29.77 acc=0.423 latent_std=0.305 cos=0.248 eff_rank=33.9
# 2026-09-24 02:37:36,807 | INFO    | train | Preview saved: samples/step_006000.txt
# stage1 epoch2:  71%|████████████████████▌        | 1833/2583 [14:36<06:00,  2.08it/s, loss=3.920, recon=3.412]2026-09-24 02:45:41,777 | INFO    | stage1 | val @7000: loss=3.916 ppl=24.46 acc=0.454 latent_std=0.317 cos=0.225 eff_rank=36.3
# 2026-09-24 02:45:45,378 | INFO    | train | Preview saved: samples/step_007000.txt
# stage1 epoch2: 100%|█████████████████████████████| 2583/2583 [20:50<00:00,  2.07it/s, loss=3.796, recon=3.287]
# stage1 epoch3:  10%|██▉                           | 250/2583 [01:54<16:33,  2.35it/s, loss=3.403, recon=2.899]2026-09-24 02:53:50,414 | INFO    | stage1 | val @8000: loss=3.733 ppl=20.69 acc=0.478 latent_std=0.321 cos=0.220 eff_rank=41.2
# 2026-09-24 02:53:53,265 | INFO    | train | Preview saved: samples/step_008000.txt
# stage1 epoch3:  48%|██████████████               | 1250/2583 [10:01<08:38,  2.57it/s, loss=2.867, recon=2.375]2026-09-24 03:01:56,838 | INFO    | stage1 | val @9000: loss=3.536 ppl=17.18 acc=0.504 latent_std=0.335 cos=0.295 eff_rank=45.7
# 2026-09-24 03:02:00,088 | INFO    | train | Preview saved: samples/step_009000.txt
# stage1 epoch3:  87%|█████████████████████████▎   | 2250/2583 [18:14<02:21,  2.36it/s, loss=3.222, recon=2.739]2026-09-24 03:10:09,931 | INFO    | stage1 | val @10000: loss=3.269 ppl=13.39 acc=0.540 latent_std=0.331 cos=0.338 eff_rank=47.2
# 2026-09-24 03:10:11,962 | INFO    | train | Preview saved: samples/step_010000.txt
# stage1 epoch3: 100%|█████████████████████████████| 2583/2583 [21:11<00:00,  2.03it/s, loss=2.988, recon=2.508]
# stage1 epoch4:  26%|███████▋                      | 667/2583 [05:07<13:55,  2.29it/s, loss=2.520, recon=2.050]2026-09-24 03:18:14,533 | INFO    | stage1 | val @11000: loss=3.031 ppl=10.57 acc=0.572 latent_std=0.353 cos=0.345 eff_rank=50.0
# 2026-09-24 03:18:16,731 | INFO    | train | Preview saved: samples/step_011000.txt
# stage1 epoch4:  65%|██████████████████▋          | 1667/2583 [13:14<07:06,  2.15it/s, loss=1.956, recon=1.492]2026-09-24 03:26:21,662 | INFO    | stage1 | val @12000: loss=2.866 ppl=9.05 acc=0.592 latent_std=0.356 cos=0.337 eff_rank=53.1
# 2026-09-24 03:26:22,600 | INFO    | train | Preview saved: samples/step_012000.txt
# stage1 epoch4: 100%|█████████████████████████████| 2583/2583 [20:47<00:00,  2.07it/s, loss=2.089, recon=1.637]
# stage1 epoch5:   3%|█                              | 84/2583 [00:40<20:42,  2.01it/s, loss=1.780, recon=1.333]2026-09-24 03:34:35,181 | INFO    | stage1 | val @13000: loss=2.727 ppl=7.93 acc=0.614 latent_std=0.358 cos=0.344 eff_rank=54.8
# 2026-09-24 03:34:37,942 | INFO    | train | Preview saved: samples/step_013000.txt
# stage1 epoch5:  42%|████████████▏                | 1084/2583 [08:48<11:25,  2.19it/s, loss=1.789, recon=1.336]2026-09-24 03:42:43,347 | INFO    | stage1 | val @14000: loss=2.664 ppl=7.53 acc=0.625 latent_std=0.366 cos=0.362 eff_rank=55.7
# 2026-09-24 03:42:44,329 | INFO    | train | Preview saved: samples/step_014000.txt
# stage1 epoch5:  81%|███████████████████████▍     | 2084/2583 [17:00<03:45,  2.21it/s, loss=1.896, recon=1.455]2026-09-24 03:50:55,419 | INFO    | stage1 | val @15000: loss=2.584 ppl=6.99 acc=0.637 latent_std=0.373 cos=0.387 eff_rank=54.0
# 2026-09-24 03:50:58,311 | INFO    | train | Preview saved: samples/step_015000.txt
# stage1 epoch5: 100%|█████████████████████████████| 2583/2583 [21:13<00:00,  2.03it/s, loss=1.698, recon=1.251]
# stage1 epoch6:  19%|█████▊                        | 501/2583 [04:00<15:13,  2.28it/s, loss=1.492, recon=1.051]2026-09-24 03:59:08,398 | INFO    | stage1 | val @16000: loss=2.547 ppl=6.83 acc=0.646 latent_std=0.362 cos=0.319 eff_rank=58.2
# 2026-09-24 03:59:09,863 | INFO    | train | Preview saved: samples/step_016000.txt
# stage1 epoch6:  58%|████████████████▊            | 1501/2583 [12:05<07:34,  2.38it/s, loss=1.339, recon=0.905]2026-09-24 04:07:13,751 | INFO    | stage1 | val @17000: loss=2.521 ppl=6.71 acc=0.655 latent_std=0.371 cos=0.348 eff_rank=57.4
# 2026-09-24 04:07:16,977 | INFO    | train | Preview saved: samples/step_017000.txt
# stage1 epoch6:  97%|████████████████████████████ | 2501/2583 [20:12<00:31,  2.56it/s, loss=1.447, recon=1.013]2026-09-24 04:15:20,219 | INFO    | stage1 | val @18000: loss=2.490 ppl=6.55 acc=0.661 latent_std=0.366 cos=0.330 eff_rank=57.3
# 2026-09-24 04:15:21,492 | INFO    | train | Preview saved: samples/step_018000.txt
# stage1 epoch6: 100%|█████████████████████████████| 2583/2583 [21:11<00:00,  2.03it/s, loss=1.360, recon=0.926]
# stage1 epoch7:   0%|▏                                                        | 7/2583 [00:03<20:55,  2.05it/s]^C
# stage1 epoch7:   0%|▏                                                        | 7/2583 [00:03<21:02,  2.04it/s]
# Traceback (most recent call last):
#   File "/kaggle/working/SemanticTransformWrapper/train_stage1.py", line 56, in <module>
#     main()
#   File "/kaggle/working/SemanticTransformWrapper/train_stage1.py", line 52, in main
#     train_stage1(cfg, resume=args.resume)
#   File "/kaggle/working/SemanticTransformWrapper/src/training/stage1.py", line 140, in train_stage1
#     (loss / cfg.train.grad_accum).backward()
#   File "/usr/local/lib/python3.12/dist-packages/torch/_tensor.py", line 630, in backward
#     torch.autograd.backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py", line 364, in backward
#     _engine_run_backward(
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py", line 865, in _engine_run_backward
#     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python train_stage2.py --stage1-checkpoint checkpoints/stage1/best.pt
# Out:
# stage2[bihopfield] epoch0:   2%|▊                                           | 49/2583 [00:10<08:08,  5.19it/s]/kaggle/working/SemanticTransformWrapper/src/training/stage2.py:167: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   writer.add_scalar("loss/latent", float(lset["latent"]), gstep)
# stage2[bihopfield] epoch0:  39%|███▍     | 999/2583 [03:32<05:19,  4.96it/s, dec=3.199, lat=0.186, loss=3.385]2026-09-24 04:20:20,270 | INFO    | stage2 | val @1000: loss=4.051 decode=3.875 latent=0.177 ppl=54.57 dep=1.520
# 2026-09-24 04:20:21,751 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_001000.txt
# stage2[bihopfield] epoch0:  77%|██████▏ | 1999/2583 [07:26<02:40,  3.64it/s, dec=2.934, lat=0.125, loss=3.060]2026-09-24 04:24:14,880 | INFO    | stage2 | val @2000: loss=3.919 decode=3.789 latent=0.130 ppl=50.06 dep=1.606
# 2026-09-24 04:24:16,956 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_002000.txt
# stage2[bihopfield] epoch0: 100%|████████| 2583/2583 [09:56<00:00,  4.33it/s, dec=2.826, lat=0.104, loss=2.929]
# stage2[bihopfield] epoch1:  16%|█▍       | 416/2583 [01:27<06:48,  5.30it/s, dec=2.501, lat=0.117, loss=2.617]2026-09-24 04:28:11,464 | INFO    | stage2 | val @3000: loss=3.867 decode=3.753 latent=0.114 ppl=48.56 dep=1.642
# 2026-09-24 04:28:12,990 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_003000.txt
# stage2[bihopfield] epoch1:  55%|████▍   | 1416/2583 [05:22<04:13,  4.61it/s, dec=3.248, lat=0.114, loss=3.362]2026-09-24 04:32:07,008 | INFO    | stage2 | val @4000: loss=3.838 decode=3.730 latent=0.109 ppl=47.39 dep=1.665
# 2026-09-24 04:32:08,343 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_004000.txt
# stage2[bihopfield] epoch1:  94%|███████▍| 2416/2583 [09:20<00:35,  4.68it/s, dec=2.820, lat=0.097, loss=2.917]2026-09-24 04:36:04,287 | INFO    | stage2 | val @5000: loss=3.815 decode=3.713 latent=0.102 ppl=46.58 dep=1.682
# 2026-09-24 04:36:05,524 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_005000.txt
# stage2[bihopfield] epoch1: 100%|████████| 2583/2583 [10:17<00:00,  4.18it/s, dec=2.598, lat=0.100, loss=2.698]
# stage2[bihopfield] epoch2:  32%|██▉      | 833/2583 [02:55<06:07,  4.76it/s, dec=2.676, lat=0.101, loss=2.778]2026-09-24 04:39:57,486 | INFO    | stage2 | val @6000: loss=3.813 decode=3.714 latent=0.099 ppl=46.70 dep=1.681
# 2026-09-24 04:39:58,848 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_006000.txt
# stage2[bihopfield] epoch2:  71%|█████▋  | 1833/2583 [06:49<02:30,  4.98it/s, dec=2.759, lat=0.084, loss=2.843]2026-09-24 04:43:51,862 | INFO    | stage2 | val @7000: loss=3.793 decode=3.697 latent=0.096 ppl=45.87 dep=1.698
# 2026-09-24 04:43:53,027 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_007000.txt
# stage2[bihopfield] epoch2: 100%|████████| 2583/2583 [09:52<00:00,  4.36it/s, dec=2.986, lat=0.091, loss=3.078]
# stage2[bihopfield] epoch3:  10%|▊        | 250/2583 [00:53<07:20,  5.30it/s, dec=3.015, lat=0.101, loss=3.116]2026-09-24 04:47:48,484 | INFO    | stage2 | val @8000: loss=3.787 decode=3.692 latent=0.095 ppl=45.70 dep=1.703
# 2026-09-24 04:47:49,837 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_008000.txt
# stage2[bihopfield] epoch3:  48%|███▊    | 1250/2583 [04:49<04:42,  4.72it/s, dec=2.710, lat=0.103, loss=2.812]2026-09-24 04:51:43,950 | INFO    | stage2 | val @9000: loss=3.781 decode=3.685 latent=0.096 ppl=45.25 dep=1.710
# 2026-09-24 04:51:45,475 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_009000.txt
# stage2[bihopfield] epoch3:  87%|██████▉ | 2250/2583 [08:42<01:17,  4.28it/s, dec=2.441, lat=0.092, loss=2.533]2026-09-24 04:55:37,052 | INFO    | stage2 | val @10000: loss=3.781 decode=3.689 latent=0.092 ppl=45.50 dep=1.706
# 2026-09-24 04:55:38,595 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_010000.txt
# stage2[bihopfield] epoch3: 100%|████████| 2583/2583 [10:15<00:00,  4.20it/s, dec=2.534, lat=0.096, loss=2.630]
# stage2[bihopfield] epoch4:  26%|██▎      | 667/2583 [02:22<06:28,  4.94it/s, dec=2.728, lat=0.092, loss=2.820]2026-09-24 04:59:32,143 | INFO    | stage2 | val @11000: loss=3.768 decode=3.675 latent=0.092 ppl=44.80 dep=1.720
# 2026-09-24 04:59:33,648 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_011000.txt
# stage2[bihopfield] epoch4:  65%|█████▏  | 1667/2583 [06:14<02:54,  5.24it/s, dec=2.914, lat=0.096, loss=3.010]2026-09-24 05:03:24,901 | INFO    | stage2 | val @12000: loss=3.754 decode=3.664 latent=0.091 ppl=44.50 dep=1.731
# 2026-09-24 05:03:26,819 | INFO    | train | Preview saved: samples/stage2_bihopfield/step_012000.txt
# stage2[bihopfield] epoch4: 100%|████████| 2583/2583 [09:52<00:00,  4.36it/s, dec=3.018, lat=0.094, loss=3.112]
# stage2[bihopfield] epoch5:   3%|▎         | 84/2583 [00:17<09:52,  4.22it/s, dec=2.661, lat=0.088, loss=2.749]^C
# stage2[bihopfield] epoch5:   3%|▎         | 84/2583 [00:23<11:30,  3.62it/s, dec=2.661, lat=0.088, loss=2.749]
# Traceback (most recent call last):
#   File "/kaggle/working/SemanticTransformWrapper/train_stage2.py", line 61, in <module>
#     main()
#   File "/kaggle/working/SemanticTransformWrapper/train_stage2.py", line 56, in main
#     train_stage2(cfg, args.stage1_checkpoint, resume=args.resume,
#   File "/kaggle/working/SemanticTransformWrapper/src/training/stage2.py", line 175, in train_stage2
#     vs = validate_stage2(model, val_loader, cfg, device, tok.pad_id)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/utils/_contextlib.py", line 124, in decorate_context
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/training/stage2.py", line 45, in validate_stage2
#     out = model(prompt, pmask, target, tmask)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/model/model.py", line 120, in forward
#     z_pred = self.transform(z_p)
#              ^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/model/model.py", line 107, in transform
#     return self.core(z_prompt)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1776, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1787, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/kaggle/working/SemanticTransformWrapper/src/model/cores.py", line 131, in forward
#     attn = torch.softmax(self.beta * state @ state.transpose(-1, -2), dim=-1)
#                                              ^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "Do you like watch "
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.2888
# generated    : Do you like watch ivory ?

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "The weather today is clear, so "
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.2023
# generated    : The weather today is clear, so ivating in summer .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "Birds have "
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.1562
# generated    : Birds have ivated .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "The sun today is"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.2608
# generated    : The sun today is a big mistake .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "Something goes wrong with"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.3083
# generated    : Something goes wrong with my friends .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "The mooncakes are"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.3819
# generated    : The mooncakes are not usually available .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "My mother"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.0286
# generated    : My mother-in-law is driving me up .

# %%
# !python generate.py --checkpoint checkpoints/stage2/best.pt --prompt "So what do you think of"
# Out:
# latent shape : (1, 32, 512)
# latent norm  : 28.3241
# generated    : So what do you think of the job ?
