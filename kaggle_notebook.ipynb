# %%
# !git clone https://github.com/kuankuancjh2/SemanticTransformWrapper
# Out:
# Cloning into 'SemanticTransformWrapper'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (41/41), done.
# remote: Total 48 (delta 3), reused 48 (delta 3), pack-reused 0 (from 0)
# Receiving objects: 100% (48/48), 44.12 KiB | 1.00 MiB/s, done.
# Resolving deltas: 100% (3/3), done.

# %%
cd SemanticTransformWrapper
# Out:
# /kaggle/working/SemanticTransformWrapper

# %%
# !python prepare_data.py
# Out:
# 2026-09-23 15:06:28,086 | INFO    | numexpr.utils | NumExpr defaulting to 4 threads.
# 2026-09-23 15:06:29,809 | INFO    | datasets | TensorFlow version 2.20.0 available.
# 2026-09-23 15:06:29,814 | INFO    | datasets | JAX version 0.7.2 available.
# 2026-09-23 15:06:32,152 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/refs%2Fconvert%2Fparquet/README.md "HTTP/1.1 404 Not Found"
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-23 15:06:32,153 | WARNING | huggingface_hub.utils._http | Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-09-23 15:06:32,256 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/revision/refs%2Fconvert%2Fparquet "HTTP/1.1 200 OK"
# 2026-09-23 15:06:32,315 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/dailydialog.py "HTTP/1.1 404 Not Found"
# 2026-09-23 15:06:32,470 | INFO    | httpx | HTTP Request: HEAD https://s3.amazonaws.com/datasets.huggingface.co/datasets/datasets/roskoN/dailydialog/roskoN/dailydialog.py "HTTP/1.1 404 Not Found"
# 2026-09-23 15:06:32,532 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/README.md "HTTP/1.1 404 Not Found"
# 2026-09-23 15:06:32,605 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/revision/f9b0ba89e62d91641632652722b479b5c65ae4b6 "HTTP/1.1 200 OK"
# 2026-09-23 15:06:32,667 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/.huggingface.yaml "HTTP/1.1 404 Not Found"
# 2026-09-23 15:06:32,753 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6/data?recursive=true&expand=false "HTTP/1.1 404 Not Found"
# 2026-09-23 15:06:32,827 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6?recursive=false&expand=false "HTTP/1.1 200 OK"
# 2026-09-23 15:06:32,899 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/tree/f9b0ba89e62d91641632652722b479b5c65ae4b6/full?recursive=true&expand=false "HTTP/1.1 200 OK"
# 2026-09-23 15:06:32,986 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/dataset_infos.json "HTTP/1.1 404 Not Found"
# 2026-09-23 15:06:33,214 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/train/0000.parquet "HTTP/1.1 302 Found"
# 2026-09-23 15:06:33,339 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/datasets/roskoN/dailydialog/xet-read-token/f9b0ba89e62d91641632652722b479b5c65ae4b6 "HTTP/1.1 200 OK"
# full/train/0000.parquet: 100%|█████████████| 3.67M/3.67M [00:00<00:00, 5.63MB/s]
# 2026-09-23 15:06:34,061 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/validation/0000.parquet "HTTP/1.1 307 Temporary Redirect"
# 2026-09-23 15:06:34,168 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Fvalidation%2F0000.parquet "HTTP/1.1 200 OK"
# 2026-09-23 15:06:34,281 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Fvalidation%2F0000.parquet "HTTP/1.1 200 OK"
# 0000.parquet: 100%|██████████████████████████| 340k/340k [00:00<00:00, 6.68MB/s]
# 2026-09-23 15:06:34,398 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/datasets/roskoN/dailydialog/resolve/f9b0ba89e62d91641632652722b479b5c65ae4b6/full/test/0000.parquet "HTTP/1.1 307 Temporary Redirect"
# 2026-09-23 15:06:34,504 | INFO    | httpx | HTTP Request: HEAD https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Ftest%2F0000.parquet "HTTP/1.1 200 OK"
# 2026-09-23 15:06:34,612 | INFO    | httpx | HTTP Request: GET https://huggingface.co/api/resolve-cache/datasets/roskoN/dailydialog/f9b0ba89e62d91641632652722b479b5c65ae4b6/full%2Ftest%2F0000.parquet "HTTP/1.1 200 OK"
# 0000.parquet: 100%|██████████████████████████| 337k/337k [00:00<00:00, 34.3MB/s]
# Generating train split: 11118 examples [00:00, 137871.48 examples/s]
# Generating validation split: 1000 examples [00:00, 119666.31 examples/s]
# Generating test split: 1000 examples [00:00, 139308.62 examples/s]
# 2026-09-23 15:06:35,681 | INFO    | prepare_data | Loaded 89861 dialogue pairs from HF dataset roskoN/dailydialog
# [00:00:00] Tokenize words                 ██████████████████ 23200    /    23200[00:00:00] Tokenize words                 ██████████████████ 0        /        0
# [00:00:00] Count pairs                    ██████████████████ 23200    /    23200
# [00:00:00] Compute merges                 ██████████████████ 15740    /    15740
# 2026-09-23 15:06:39,839 | INFO    | prepare_data | Data ready: {"source": "hf:roskoN/dailydialog", "offline_used": false, "train_size": 82673, "val_size": 3594, "test_size": 3594, "stage1_train_size": 82673, "vocab_size": 16000, "tokenizer": "data/cache/tokenizer_bpe.json", "mean_len_tokens": 15.337, "max_len_tokens": 103, "p99_len_tokens": 57}

# %%
# !python train_stage1.py
# Out:
# stage1 epoch0:   2%|█                                                       | 49/2583 [00:18<12:59,  3.25it/s]/kaggle/working/SemanticTransformWrapper/src/training/stage1.py:147: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   writer.add_scalar("loss/variance", float(l_var), gstep)
# stage1 epoch0:  39%|███████████▌                  | 999/2583 [06:51<11:45,  2.24it/s, loss=5.461, recon=4.857]2026-09-23 15:16:21,576 | INFO    | stage1 | val @1000: loss=5.468 ppl=108.32 acc=0.259 latent_std=0.283 cos=0.608 eff_rank=30.9
# 2026-09-23 15:16:25,129 | INFO    | train | Preview saved: samples/step_001000.txt
# stage1 epoch0:  77%|██████████████████████▍      | 1999/2583 [14:27<04:14,  2.29it/s, loss=4.606, recon=4.054]2026-09-23 15:23:56,990 | INFO    | stage1 | val @2000: loss=4.946 ppl=65.97 acc=0.315 latent_std=0.303 cos=0.523 eff_rank=33.0
# 2026-09-23 15:24:00,649 | INFO    | train | Preview saved: samples/step_002000.txt
# stage1 epoch0: 100%|█████████████████████████████| 2583/2583 [19:02<00:00,  2.26it/s, loss=4.325, recon=3.781]
# stage1 epoch1:  16%|████▊                         | 416/2583 [03:02<15:34,  2.32it/s, loss=4.213, recon=3.679]2026-09-23 15:31:35,157 | INFO    | stage1 | val @3000: loss=4.714 ppl=52.70 acc=0.332 latent_std=0.301 cos=0.437 eff_rank=34.6
# 2026-09-23 15:31:42,486 | INFO    | train | Preview saved: samples/step_003000.txt
# stage1 epoch1:  55%|███████████████▉             | 1416/2583 [10:42<11:43,  1.66it/s, loss=4.094, recon=3.567]2026-09-23 15:39:15,152 | INFO    | stage1 | val @4000: loss=4.475 ppl=41.77 acc=0.370 latent_std=0.295 cos=0.269 eff_rank=38.4
# 2026-09-23 15:39:20,354 | INFO    | train | Preview saved: samples/step_004000.txt
# stage1 epoch1:  94%|███████████████████████████▏ | 2416/2583 [18:19<01:00,  2.78it/s, loss=4.076, recon=3.555]2026-09-23 15:46:52,471 | INFO    | stage1 | val @5000: loss=4.315 ppl=35.72 acc=0.388 latent_std=0.297 cos=0.226 eff_rank=40.0
# 2026-09-23 15:46:58,782 | INFO    | train | Preview saved: samples/step_005000.txt
# stage1 epoch1: 100%|█████████████████████████████| 2583/2583 [19:55<00:00,  2.16it/s, loss=4.134, recon=3.618]
# stage1 epoch2:  32%|█████████▋                    | 833/2583 [06:01<12:04,  2.42it/s, loss=4.081, recon=3.570]2026-09-23 15:54:28,946 | INFO    | stage1 | val @6000: loss=4.140 ppl=30.18 acc=0.418 latent_std=0.318 cos=0.248 eff_rank=43.2
# 2026-09-23 15:54:31,807 | INFO    | train | Preview saved: samples/step_006000.txt
# stage1 epoch2:  63%|██████████████████▎          | 1626/2583 [12:02<06:06,  2.61it/s, loss=3.550, recon=3.037]
